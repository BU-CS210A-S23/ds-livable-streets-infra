# %% [markdown]
# ## Looking at Trends in Bike Lane Frequency and Bike Lane Connectivity by Census Tract

# %% [markdown]
# ### Data Importing

# %% [markdown]
# First, we will take the BikeLane GeoJSON (2023) and import all of the data from this dataset into our code. We will also manually select weights for certain types of bike lanes -- more "safe" bike lanes (separated, contraflow, shared use) would be weighed higher in our data.

# %%
data_path = '../../../data/bike-lane-applied-mid-semester/'

import geopandas as gpd
import numpy as np

df = gpd.read_file(data_path + 'Existing_Bike_Network_2023.geojson')
# print(df.geometry.iloc[0].coords[0][0])

# these weights aren't actually used :/ they have been decommissioned.
weights = {}
weights['BL'] = 1 # bike lane, single strip
weights['BL-PEAKBUS'] = 1 # bike lane, peak bus
weights['BFBL'] = 1 # bike lane, buffered strip
weights['BLSL'] = 1 # one bike lane, one shared lane
weights['CFBL'] = 3 # contraflow bike lane
weights['SBL'] = 5 # separated bike lane
weights['SBLBL'] = 3 # one separated bike lane, one painted bike lane
weights['SBLSL'] = 3 # one separated bike lane, one painted shared lane
weights['CFSBL'] = 5 # separated contraflow lane
weights['SLM'] = 1 # shared bus/bike lane
weights['SLMTC'] = 2 # calmed street shared bike lane
weights['PED'] = 4 # pedestrian plaza (allows bikes)
weights['SUP'] = 4 # shared use ped/bike path
weights['SUPN'] = 4 # shared use ped/bike natural path
weights['SUPM'] = 2 # ped-prioritized shared use path
weights['WALK'] = 1 # walk your bike path

for key in weights:
    weights[key] *= 5

# %% [markdown]
# Then, we will call the GeoCoder API from the US Government to determine which Census Tract each bike lane segment belongs to. This allows us to process the data on a standard for location, and allows us to connect all census data collected by the US Government to the data in the bike lane set. This code takes ~15 minutes to run! I've saved the results to a file "census_tracts.txt" to allow for merging with the bike lane dataset so it doesn't have to be run again.

# %%
import requests

# get census tracts for every bike lane on the geojson by coordinate
df = df.dropna()
def get_census_tract(lat, long):
    url = f'https://geocoding.geo.census.gov/geocoder/geographies/coordinates?x={lat}&y={long}&benchmark=Public_AR_Census2020&vintage=Census2020_Census2020&format=json'
    response = requests.get(url)
    data = response.json()
    
    census_tract = data['result']['geographies']['Census Tracts'][0]['BASENAME']
    return census_tract

def process_row(row):
    lat, long = row.geometry.coords[0][0], row.geometry.coords[0][1]
    census_tract = get_census_tract(lat, long)
    return census_tract

# just so if it errors we don't lose all progress
output_file = 'census_tracts.txt'

with open(output_file, 'a') as f:
    for idx, row in df.iterrows():
        try:
            census_tract = process_row(row)
            f.write(f'{census_tract}\n')
            print(f'row {idx + 1} done')
        except Exception as e:
            print(f'error in row {idx + 1}: {e}')
# Out:
# row 1 done
# row 2 done
# row 3 done
# row 4 done
# row 5 done
# row 6 done
# row 7 done
# row 8 done
# row 9 done
# row 10 done
# row 11 done
# row 12 done
# row 13 done
# row 14 done
# row 15 done
# row 16 done
# row 17 done
# row 18 done
# row 19 done
# row 20 done
# row 21 done
# row 22 done
# row 23 done
# row 24 done
# row 25 done
# row 26 done
# row 27 done
# row 28 done
# row 29 done
# row 30 done
# row 31 done
# row 32 done
# row 33 done
# row 34 done
# row 35 done
# row 36 done
# row 37 done
# row 38 done
# row 39 done
# row 40 done
# row 41 done
# row 42 done
# row 43 done
# row 44 done
# row 45 done
# row 46 done
# row 47 done
# row 48 done
# row 49 done
# row 50 done
# row 51 done
# row 52 done
# row 53 done
# row 54 done
# row 55 done
# row 56 done
# row 57 done
# row 58 done
# row 59 done
# row 60 done
# row 61 done
# row 62 done
# row 63 done
# row 64 done
# row 65 done
# row 66 done
# row 67 done
# row 68 done
# row 69 done
# row 70 done
# row 71 done
# row 72 done
# row 73 done
# row 74 done
# row 75 done
# row 76 done
# row 77 done
# row 78 done
# row 79 done
# row 80 done
# row 81 done
# row 82 done
# row 83 done
# row 84 done
# row 85 done
# row 86 done
# row 87 done
# row 88 done
# row 89 done
# row 90 done
# row 91 done
# row 92 done
# row 93 done
# row 94 done
# row 95 done
# row 96 done
# row 97 done
# row 98 done
# row 99 done
# row 100 done
# row 101 done
# row 102 done
# row 103 done
# row 104 done
# row 105 done
# row 106 done
# row 107 done
# row 108 done
# row 109 done
# row 110 done
# row 111 done
# row 112 done
# row 113 done
# row 114 done
# row 115 done
# row 116 done
# row 117 done
# row 118 done
# row 119 done
# row 120 done
# row 121 done
# row 122 done
# row 123 done
# row 124 done
# row 125 done
# row 126 done
# row 127 done
# row 128 done
# row 129 done
# row 130 done
# row 131 done
# row 132 done
# row 133 done
# row 134 done
# row 135 done
# row 136 done
# row 137 done
# row 138 done
# row 139 done
# row 140 done
# row 141 done
# row 142 done
# row 143 done
# row 144 done
# row 145 done
# row 146 done
# row 147 done
# row 148 done
# row 149 done
# row 150 done
# row 151 done
# row 152 done
# row 153 done
# row 154 done
# row 155 done
# row 156 done
# row 157 done
# row 158 done
# row 159 done
# row 160 done
# row 161 done
# row 162 done
# row 163 done
# row 164 done
# row 165 done
# row 166 done
# row 167 done
# row 168 done
# row 169 done
# row 170 done
# row 171 done
# row 172 done
# row 173 done
# row 174 done
# row 175 done
# row 176 done
# row 177 done
# row 178 done
# row 179 done
# row 180 done
# row 181 done
# row 182 done
# row 183 done
# row 184 done
# row 185 done
# row 186 done
# row 187 done
# row 188 done
# row 189 done
# row 190 done
# row 191 done
# row 192 done
# row 193 done
# row 194 done
# row 195 done
# row 196 done
# row 197 done
# row 198 done
# row 199 done
# row 200 done
# row 201 done
# row 202 done
# row 203 done
# row 204 done
# row 205 done
# row 206 done
# row 207 done
# row 208 done
# row 209 done
# row 210 done
# row 211 done
# row 212 done
# row 213 done
# row 214 done
# row 215 done
# row 216 done
# row 217 done
# row 218 done
# row 219 done
# row 220 done
# row 221 done
# row 222 done
# row 223 done
# row 224 done
# row 225 done
# row 226 done
# row 227 done
# row 228 done
# row 229 done
# row 230 done
# row 231 done
# row 232 done
# row 233 done
# row 234 done
# row 235 done
# row 236 done
# row 237 done
# row 238 done
# row 239 done
# row 240 done
# row 241 done
# row 242 done
# row 243 done
# row 244 done
# row 245 done
# row 246 done
# row 247 done
# row 248 done
# row 249 done
# row 250 done
# row 251 done
# row 252 done
# row 253 done
# row 254 done
# row 255 done
# row 256 done
# row 257 done
# row 258 done
# row 259 done
# row 260 done
# row 261 done
# row 262 done
# row 263 done
# row 264 done
# row 265 done
# row 266 done
# row 267 done
# row 268 done
# row 269 done
# row 270 done
# row 271 done
# row 272 done
# row 273 done
# row 274 done
# row 275 done
# row 276 done
# row 277 done
# row 278 done
# row 279 done
# row 280 done
# row 281 done
# row 282 done
# row 283 done
# row 284 done
# row 285 done
# row 286 done
# row 287 done
# row 288 done
# row 289 done
# row 290 done
# row 291 done
# row 292 done
# row 293 done
# row 294 done
# row 295 done
# row 296 done
# row 297 done
# row 298 done
# row 299 done
# row 300 done
# row 301 done
# row 302 done
# row 303 done
# row 304 done
# row 305 done
# row 306 done
# row 307 done
# row 308 done
# row 309 done
# row 310 done
# row 311 done
# row 312 done
# row 313 done
# row 314 done
# row 315 done
# row 316 done
# row 317 done
# row 318 done
# row 319 done
# row 320 done
# row 321 done
# row 322 done
# row 323 done
# row 324 done
# row 325 done
# row 326 done
# row 327 done
# row 328 done
# row 329 done
# row 330 done
# row 331 done
# row 332 done
# row 333 done
# row 334 done
# row 335 done
# row 336 done
# row 337 done
# row 338 done
# row 339 done
# row 340 done
# row 341 done
# row 342 done
# row 343 done
# row 344 done
# row 345 done
# row 346 done
# row 347 done
# row 348 done
# row 349 done
# row 350 done
# row 351 done
# row 352 done
# row 353 done
# row 354 done
# row 355 done
# row 356 done
# row 357 done
# row 358 done
# row 359 done
# row 360 done
# row 361 done
# row 362 done
# row 363 done
# row 364 done
# row 365 done
# row 366 done
# row 367 done
# row 368 done
# row 369 done
# row 370 done
# row 371 done
# row 372 done
# row 373 done
# row 374 done
# row 375 done
# row 376 done
# row 377 done
# row 378 done
# row 379 done
# row 380 done
# row 381 done
# row 382 done
# row 383 done
# row 384 done
# row 385 done
# row 386 done
# row 387 done
# row 388 done
# row 389 done
# row 390 done
# row 391 done
# row 392 done
# row 393 done
# row 394 done
# row 395 done
# row 396 done
# row 397 done
# row 398 done
# row 399 done
# row 400 done
# row 401 done
# row 402 done
# row 403 done
# row 404 done
# row 405 done
# row 406 done
# row 407 done
# row 408 done
# row 409 done
# row 410 done
# row 411 done
# row 412 done
# row 413 done
# row 414 done
# row 415 done
# row 416 done
# row 417 done
# row 418 done
# row 419 done
# row 420 done
# row 421 done
# row 422 done
# row 423 done
# row 424 done
# row 425 done
# row 426 done
# row 427 done
# row 428 done
# row 429 done
# row 430 done
# row 431 done
# row 432 done
# row 433 done
# row 434 done
# row 435 done
# row 436 done
# row 437 done
# row 438 done
# row 439 done
# row 440 done
# row 441 done
# row 442 done
# row 443 done
# row 444 done
# row 445 done
# row 446 done
# row 447 done
# row 448 done
# row 449 done
# row 450 done
# row 451 done
# row 452 done
# row 453 done
# row 454 done
# row 455 done
# row 456 done
# row 457 done
# row 458 done
# row 459 done
# row 460 done
# row 461 done
# row 462 done
# row 463 done
# row 464 done
# row 465 done
# row 466 done
# row 467 done
# row 468 done
# row 469 done
# row 470 done
# row 471 done
# row 472 done
# row 473 done
# row 474 done
# row 475 done
# row 476 done
# row 477 done
# row 478 done
# row 479 done
# row 480 done
# row 481 done
# row 482 done
# row 483 done
# row 484 done
# row 485 done
# row 486 done
# row 487 done
# row 488 done
# row 489 done
# row 490 done
# row 491 done
# row 492 done
# row 493 done
# row 494 done
# row 495 done
# row 496 done
# row 497 done
# row 498 done
# row 499 done
# row 500 done
# row 501 done
# row 502 done
# row 503 done
# row 504 done
# row 505 done
# row 506 done
# row 507 done
# row 508 done
# row 509 done
# row 510 done
# row 511 done
# row 512 done
# row 513 done
# row 514 done
# row 515 done
# row 516 done
# row 517 done
# row 518 done
# row 519 done
# row 520 done
# row 521 done
# row 522 done
# row 523 done
# row 524 done
# row 525 done
# row 526 done
# row 527 done
# row 528 done
# row 529 done
# row 530 done
# row 531 done
# row 532 done
# row 533 done
# row 534 done
# row 535 done
# row 536 done
# row 537 done
# row 538 done
# row 539 done
# row 540 done
# row 541 done
# row 542 done
# row 543 done
# row 544 done
# row 545 done
# row 546 done
# row 547 done
# row 548 done
# row 549 done
# row 550 done
# row 551 done
# row 552 done
# row 553 done
# row 554 done
# row 555 done
# row 556 done
# row 557 done
# row 558 done
# row 559 done
# row 560 done
# row 561 done
# row 562 done
# row 563 done
# row 564 done
# row 565 done
# row 566 done
# row 567 done
# row 568 done
# row 569 done
# row 570 done
# row 571 done
# row 572 done
# row 573 done
# row 574 done
# row 575 done
# row 576 done
# row 577 done
# row 578 done
# row 579 done
# row 580 done
# row 581 done
# row 582 done
# row 583 done
# row 584 done
# row 585 done
# row 586 done
# row 587 done
# row 588 done
# row 589 done
# row 590 done
# row 591 done
# row 592 done
# row 593 done
# row 594 done
# row 595 done
# row 596 done
# row 597 done
# row 598 done
# row 599 done
# row 600 done
# row 601 done
# row 602 done
# row 603 done
# row 604 done
# row 605 done
# row 606 done
# row 607 done
# row 608 done
# row 609 done
# row 610 done
# row 611 done
# row 612 done
# row 613 done
# row 614 done
# row 615 done
# row 616 done
# row 617 done
# row 618 done
# row 619 done
# row 620 done
# row 621 done
# row 622 done
# row 623 done
# row 624 done
# row 625 done
# row 626 done
# row 627 done
# row 628 done
# row 629 done
# row 630 done
# row 631 done
# row 632 done
# row 633 done
# row 634 done
# row 635 done
# row 636 done
# row 637 done
# row 638 done
# row 639 done
# row 640 done
# row 641 done
# row 642 done
# row 643 done
# row 644 done
# row 645 done
# row 646 done
# row 647 done
# row 648 done
# row 649 done
# row 650 done
# row 651 done
# row 652 done
# row 653 done
# row 654 done
# row 655 done
# row 656 done
# row 657 done
# row 658 done
# row 659 done
# row 660 done
# row 661 done
# row 662 done
# row 663 done
# row 664 done
# row 665 done
# row 666 done
# row 667 done
# row 668 done
# row 669 done
# row 670 done
# row 671 done
# row 672 done
# row 673 done
# row 674 done
# row 675 done
# row 676 done
# row 677 done
# row 678 done
# row 679 done
# row 680 done
# row 681 done
# row 682 done
# row 683 done
# row 684 done
# row 685 done
# row 686 done
# row 687 done
# row 688 done
# row 689 done
# row 690 done
# row 691 done
# row 692 done
# row 693 done
# row 694 done
# row 695 done
# row 696 done
# row 697 done
# row 698 done
# row 699 done
# row 700 done
# row 701 done
# row 702 done
# row 703 done
# row 704 done
# row 705 done
# row 706 done
# row 707 done
# row 708 done
# row 709 done
# row 710 done
# row 711 done
# row 712 done
# row 713 done
# row 714 done
# row 715 done
# row 716 done
# row 717 done
# row 718 done
# row 719 done
# row 720 done
# row 721 done
# row 722 done
# row 723 done
# row 724 done
# row 725 done
# row 726 done
# row 727 done
# row 728 done
# row 729 done
# row 730 done
# row 731 done
# row 732 done
# row 733 done
# row 734 done
# row 735 done
# row 736 done
# row 737 done
# row 738 done
# row 739 done
# row 740 done
# row 741 done
# row 742 done
# row 743 done
# row 744 done
# row 745 done
# row 746 done
# row 747 done
# row 748 done
# row 749 done
# row 750 done
# row 751 done
# row 752 done
# row 753 done
# row 754 done
# row 755 done
# row 756 done
# row 757 done
# row 758 done
# row 759 done
# row 760 done
# row 761 done
# row 762 done
# row 763 done
# row 764 done
# row 765 done
# row 766 done
# row 767 done
# row 768 done
# row 769 done
# row 770 done
# row 771 done
# row 772 done
# row 773 done
# row 774 done
# row 775 done
# row 776 done
# row 777 done
# row 778 done
# row 779 done
# row 780 done
# row 781 done
# row 782 done
# row 783 done
# row 784 done
# row 785 done
# row 786 done
# row 787 done
# row 788 done
# row 789 done
# row 790 done
# row 791 done
# row 792 done
# row 793 done
# row 794 done
# row 795 done
# row 796 done
# row 797 done
# row 798 done
# row 799 done
# row 800 done
# row 801 done
# row 802 done
# row 803 done
# row 804 done
# row 805 done
# row 806 done
# row 807 done
# row 808 done
# row 809 done
# row 810 done
# row 811 done
# row 812 done
# row 813 done
# row 814 done
# row 815 done
# row 816 done
# row 817 done
# row 818 done
# row 819 done
# row 820 done
# row 821 done
# row 822 done
# row 823 done
# row 824 done
# row 825 done
# row 826 done
# row 827 done
# row 828 done
# row 829 done
# row 830 done
# row 831 done
# row 832 done
# row 833 done
# row 834 done
# row 835 done
# row 836 done
# row 837 done
# row 838 done
# row 839 done
# row 840 done
# row 841 done
# row 842 done
# row 843 done
# row 844 done
# row 845 done
# row 846 done
# row 847 done
# row 848 done
# row 849 done
# row 850 done
# row 851 done
# row 852 done
# row 853 done
# row 854 done
# row 855 done
# row 856 done
# row 857 done
# row 858 done
# row 859 done
# row 860 done
# row 861 done
# row 862 done
# row 863 done
# row 864 done
# row 865 done
# row 866 done
# row 867 done
# row 868 done
# row 869 done
# row 870 done
# row 871 done
# row 872 done
# row 873 done
# row 874 done
# row 875 done
# row 876 done
# row 877 done
# row 878 done
# row 879 done
# row 880 done
# row 881 done
# row 882 done
# row 883 done
# row 884 done
# row 885 done
# row 886 done
# row 887 done
# row 888 done
# row 889 done
# row 890 done
# row 891 done
# row 892 done
# row 893 done
# row 894 done
# row 895 done
# row 896 done
# row 897 done
# row 898 done
# row 899 done
# row 900 done
# row 901 done
# row 902 done
# row 903 done
# row 904 done
# row 905 done
# row 906 done
# row 907 done
# row 908 done
# row 909 done
# row 910 done
# row 911 done
# row 912 done
# row 913 done
# row 914 done
# row 915 done
# row 916 done
# row 917 done
# row 918 done
# row 919 done
# row 920 done
# row 921 done
# row 922 done
# row 923 done
# row 924 done
# row 925 done
# row 926 done
# row 927 done
# row 928 done
# row 929 done
# row 930 done
# row 931 done
# row 932 done
# row 933 done
# row 934 done
# row 935 done
# row 936 done
# row 937 done
# row 938 done
# row 939 done
# row 940 done
# row 941 done
# row 942 done
# row 943 done
# row 944 done
# row 945 done
# row 946 done
# row 947 done
# row 948 done
# row 949 done
# row 950 done
# row 951 done
# row 952 done
# row 953 done
# row 954 done
# row 955 done
# row 956 done
# row 957 done
# row 958 done
# row 959 done
# row 960 done
# row 961 done
# row 962 done
# row 963 done
# row 964 done
# row 965 done
# row 966 done
# row 967 done
# row 968 done
# row 969 done
# row 970 done
# row 971 done
# row 972 done
# row 973 done
# row 974 done
# row 975 done
# row 976 done
# row 977 done
# row 978 done
# row 979 done
# row 980 done
# row 981 done
# row 982 done
# row 983 done
# row 984 done
# row 985 done
# row 986 done
# row 987 done
# row 988 done
# row 989 done
# row 990 done
# row 991 done
# row 992 done
# row 993 done
# row 994 done
# row 995 done
# row 996 done
# row 997 done
# row 998 done
# row 999 done
# row 1000 done
# row 1001 done
# row 1002 done
# row 1003 done
# row 1004 done
# row 1005 done
# row 1006 done
# row 1007 done
# row 1008 done
# row 1009 done
# row 1010 done
# row 1011 done
# row 1012 done
# row 1013 done
# row 1014 done
# row 1015 done
# row 1016 done
# row 1017 done
# row 1018 done
# row 1019 done
# row 1020 done
# row 1021 done
# row 1022 done
# row 1023 done
# row 1024 done
# row 1025 done
# row 1026 done
# row 1027 done
# row 1028 done
# row 1029 done
# row 1030 done
# row 1031 done
# row 1032 done
# row 1033 done
# row 1034 done
# row 1035 done
# row 1036 done
# row 1037 done
# row 1038 done
# row 1039 done
# row 1040 done
# row 1041 done
# row 1042 done
# row 1043 done
# row 1044 done
# row 1045 done
# row 1046 done
# row 1047 done
# row 1048 done
# row 1049 done
# row 1050 done
# row 1051 done
# row 1052 done
# row 1053 done
# row 1054 done
# row 1055 done
# row 1056 done
# row 1057 done
# row 1058 done
# row 1059 done
# row 1060 done
# row 1061 done
# row 1062 done
# row 1063 done
# row 1064 done
# row 1065 done
# row 1066 done
# row 1067 done
# row 1068 done
# row 1069 done
# row 1070 done
# row 1071 done
# row 1072 done
# row 1073 done
# row 1074 done
# row 1075 done
# row 1076 done
# row 1077 done
# row 1078 done
# row 1079 done
# row 1080 done
# row 1081 done
# row 1082 done
# row 1083 done
# row 1084 done
# row 1085 done
# row 1086 done
# row 1087 done
# row 1088 done
# row 1089 done
# row 1090 done
# row 1091 done
# row 1092 done
# row 1093 done
# row 1094 done
# row 1095 done
# row 1096 done
# row 1097 done
# row 1098 done
# row 1099 done
# row 1100 done
# row 1101 done
# row 1102 done
# row 1103 done
# row 1104 done
# row 1105 done
# row 1106 done
# row 1107 done
# row 1108 done
# row 1109 done
# row 1110 done
# row 1111 done
# row 1112 done
# row 1113 done
# row 1114 done
# row 1115 done
# row 1116 done
# row 1117 done
# row 1118 done
# row 1119 done
# row 1120 done
# row 1121 done
# row 1122 done
# row 1123 done
# row 1124 done
# row 1125 done
# row 1126 done
# row 1127 done
# row 1128 done
# row 1129 done
# row 1130 done
# row 1131 done
# row 1132 done
# row 1133 done
# row 1134 done
# row 1135 done
# row 1136 done
# row 1137 done
# row 1138 done
# row 1139 done
# row 1140 done
# row 1141 done
# row 1142 done
# row 1143 done
# row 1144 done
# row 1145 done
# row 1146 done
# row 1147 done
# row 1148 done
# row 1149 done
# row 1150 done
# row 1151 done
# row 1152 done
# row 1153 done
# row 1154 done
# row 1155 done
# row 1156 done
# row 1157 done
# row 1158 done
# row 1159 done
# row 1160 done
# row 1161 done
# row 1162 done
# row 1163 done
# row 1164 done
# row 1165 done
# row 1166 done
# row 1167 done
# row 1168 done
# row 1169 done
# row 1170 done
# row 1171 done
# row 1172 done
# row 1173 done
# row 1174 done
# row 1175 done
# row 1176 done
# row 1177 done
# row 1178 done
# row 1179 done
# row 1180 done
# row 1181 done
# row 1182 done
# row 1183 done
# row 1184 done
# row 1185 done
# row 1186 done
# row 1187 done
# row 1188 done
# row 1189 done
# row 1190 done
# row 1191 done
# row 1192 done
# row 1193 done
# row 1194 done
# row 1195 done
# row 1196 done
# row 1197 done
# row 1198 done
# row 1199 done
# row 1200 done
# row 1201 done
# row 1202 done
# row 1203 done
# row 1204 done
# row 1205 done
# row 1206 done
# row 1207 done
# row 1208 done
# row 1209 done
# row 1210 done
# row 1211 done
# row 1212 done
# row 1213 done
# row 1214 done
# row 1215 done
# row 1216 done
# row 1217 done
# row 1218 done
# row 1219 done
# row 1220 done
# row 1221 done
# row 1222 done
# row 1223 done
# row 1224 done
# row 1225 done
# row 1226 done
# row 1227 done
# row 1228 done
# row 1229 done
# row 1230 done
# row 1231 done
# row 1232 done
# row 1233 done
# row 1234 done
# row 1235 done
# row 1236 done
# row 1237 done
# row 1238 done
# row 1239 done
# row 1240 done
# row 1241 done
# row 1242 done
# row 1243 done
# row 1244 done
# row 1245 done
# row 1246 done
# row 1247 done
# row 1248 done
# row 1249 done
# row 1250 done
# row 1251 done
# row 1252 done
# row 1253 done
# row 1254 done
# row 1255 done
# row 1256 done
# row 1257 done
# row 1258 done
# row 1259 done
# row 1260 done
# row 1261 done
# row 1262 done
# row 1263 done
# row 1264 done
# row 1265 done
# row 1266 done
# row 1267 done
# row 1268 done
# row 1269 done
# row 1270 done
# row 1271 done
# row 1272 done
# row 1273 done
# row 1274 done
# row 1275 done
# row 1276 done
# row 1277 done
# row 1278 done
# row 1279 done
# row 1280 done
# row 1281 done
# row 1282 done
# row 1283 done
# row 1284 done
# row 1285 done
# row 1286 done
# row 1287 done
# row 1288 done
# row 1289 done
# row 1290 done
# row 1291 done
# row 1292 done
# row 1293 done
# row 1294 done
# row 1295 done
# row 1296 done
# row 1297 done
# row 1298 done
# row 1299 done
# row 1300 done
# row 1301 done
# row 1302 done
# row 1303 done
# row 1304 done
# row 1305 done
# row 1306 done
# row 1307 done
# row 1308 done
# row 1309 done
# row 1310 done
# row 1311 done
# row 1312 done
# row 1313 done
# row 1314 done
# row 1315 done
# row 1316 done
# row 1317 done
# row 1318 done
# row 1319 done
# row 1320 done
# row 1321 done
# row 1322 done
# row 1323 done
# row 1324 done
# row 1325 done
# row 1326 done
# row 1327 done
# row 1328 done
# row 1329 done
# row 1330 done
# row 1331 done
# row 1332 done
# row 1333 done
# row 1334 done
# row 1335 done
# row 1336 done
# row 1337 done
# row 1338 done
# row 1339 done
# row 1340 done
# row 1341 done
# row 1342 done
# row 1343 done
# row 1344 done
# row 1345 done
# row 1346 done
# row 1347 done
# row 1348 done
# row 1349 done
# row 1350 done
# row 1351 done
# row 1352 done
# row 1353 done
# row 1354 done
# row 1355 done
# row 1356 done
# row 1357 done
# row 1358 done
# row 1359 done
# row 1360 done
# row 1361 done
# row 1362 done
# row 1363 done
# row 1364 done
# row 1365 done
# row 1366 done
# row 1367 done
# row 1368 done
# row 1369 done
# row 1370 done
# row 1371 done
# row 1372 done
# row 1373 done
# row 1374 done
# row 1375 done
# row 1376 done
# row 1377 done
# row 1378 done
# row 1379 done
# row 1380 done
# row 1381 done
# row 1382 done
# row 1383 done
# row 1384 done
# row 1385 done
# row 1386 done
# row 1387 done
# row 1388 done
# row 1389 done
# row 1390 done
# row 1391 done
# row 1392 done
# row 1393 done
# row 1394 done
# row 1395 done
# row 1396 done
# row 1397 done
# row 1398 done
# row 1399 done
# row 1400 done
# row 1401 done
# row 1402 done
# row 1403 done
# row 1404 done
# row 1405 done
# row 1406 done
# row 1407 done
# row 1408 done
# row 1409 done
# row 1410 done
# row 1411 done
# row 1412 done
# row 1413 done
# row 1414 done
# row 1415 done
# row 1416 done
# row 1417 done
# row 1418 done
# row 1419 done
# row 1420 done
# row 1421 done
# row 1422 done
# row 1423 done
# row 1424 done
# row 1425 done
# row 1426 done
# row 1427 done
# row 1428 done
# row 1429 done
# row 1430 done
# row 1431 done
# row 1432 done
# row 1433 done
# row 1434 done
# row 1435 done
# row 1436 done
# row 1437 done
# row 1438 done
# row 1439 done
# row 1440 done
# row 1441 done
# row 1442 done
# row 1443 done
# row 1444 done
# row 1445 done
# row 1446 done
# row 1447 done
# row 1448 done
# row 1449 done
# row 1450 done
# row 1451 done
# row 1452 done
# row 1453 done
# row 1454 done
# row 1455 done
# row 1456 done
# row 1457 done
# row 1458 done
# row 1459 done
# row 1460 done
# row 1461 done
# row 1462 done
# row 1463 done
# row 1464 done
# row 1465 done
# row 1466 done
# row 1467 done
# row 1468 done
# row 1469 done
# row 1470 done
# row 1471 done
# row 1472 done
# row 1473 done
# row 1474 done
# row 1475 done
# row 1476 done
# row 1477 done
# row 1478 done
# row 1479 done
# row 1480 done
# row 1481 done
# row 1482 done
# row 1483 done
# row 1484 done
# row 1485 done
# row 1486 done
# row 1487 done
# row 1488 done
# row 1489 done
# row 1490 done
# row 1491 done
# row 1492 done
# row 1493 done
# row 1494 done
# row 1495 done
# row 1496 done
# row 1497 done
# row 1498 done
# row 1499 done
# row 1500 done
# row 1501 done
# row 1502 done
# row 1503 done
# row 1504 done
# row 1505 done
# row 1506 done
# row 1507 done
# row 1508 done
# row 1509 done
# row 1510 done
# row 1511 done
# row 1512 done
# row 1513 done
# row 1514 done
# row 1515 done
# row 1516 done
# row 1517 done
# row 1518 done
# row 1519 done
# row 1520 done
# row 1521 done
# row 1522 done
# row 1523 done
# row 1524 done
# row 1525 done
# row 1526 done
# row 1527 done
# row 1528 done
# row 1529 done
# row 1530 done
# row 1531 done
# row 1532 done
# row 1533 done
# row 1534 done
# row 1535 done
# row 1536 done
# row 1537 done
# row 1538 done
# row 1539 done
# row 1540 done
# row 1541 done
# row 1542 done
# row 1543 done
# row 1544 done
# row 1545 done
# row 1546 done
# row 1547 done
# row 1548 done
# row 1549 done
# row 1550 done
# row 1551 done
# row 1552 done
# row 1553 done
# row 1554 done
# row 1555 done
# row 1556 done
# row 1557 done
# row 1558 done
# row 1559 done
# row 1560 done
# row 1561 done
# row 1562 done
# row 1563 done
# row 1564 done
# row 1565 done
# row 1566 done
# row 1567 done
# row 1568 done
# row 1569 done
# row 1570 done
# row 1571 done
# row 1572 done
# row 1573 done
# row 1574 done
# row 1575 done
# row 1576 done
# row 1577 done
# row 1578 done
# row 1579 done
# row 1580 done
# row 1581 done
# row 1582 done
# row 1583 done
# row 1584 done
# row 1585 done
# row 1586 done
# row 1587 done
# row 1588 done
# row 1589 done
# row 1590 done
# row 1591 done
# row 1592 done
# row 1593 done
# row 1594 done
# row 1595 done
# row 1596 done
# row 1597 done
# row 1598 done
# row 1599 done
# row 1600 done
# row 1601 done
# row 1602 done
# row 1603 done
# row 1604 done
# row 1605 done
# row 1606 done
# row 1607 done
# row 1608 done
# row 1609 done
# row 1610 done
# row 1611 done
# row 1612 done
# row 1613 done
# row 1614 done
# row 1615 done
# row 1616 done
# row 1617 done
# row 1618 done
# row 1619 done
# row 1620 done
# row 1621 done
# row 1622 done
# row 1623 done
# row 1624 done
# row 1625 done
# row 1626 done
# row 1627 done
# row 1628 done
# row 1629 done
# row 1630 done
# row 1631 done
# row 1632 done
# row 1633 done
# row 1634 done
# row 1635 done
# row 1636 done
# row 1637 done
# row 1638 done
# row 1639 done
# row 1640 done
# row 1641 done
# row 1642 done
# row 1643 done
# row 1644 done
# row 1645 done
# row 1646 done
# row 1647 done
# row 1648 done
# row 1649 done
# row 1650 done
# row 1651 done
# row 1652 done
# row 1653 done
# row 1654 done
# row 1655 done
# row 1656 done
# row 1657 done
# row 1658 done
# row 1659 done
# row 1660 done
# row 1661 done
# row 1662 done
# row 1663 done
# row 1664 done
# row 1665 done
# row 1666 done
# row 1667 done
# row 1668 done
# row 1669 done
# row 1670 done
# row 1671 done
# row 1672 done
# row 1673 done
# row 1674 done
# row 1675 done
# row 1676 done
# row 1677 done
# row 1678 done
# row 1679 done
# row 1680 done
# row 1681 done
# row 1682 done
# row 1683 done
# row 1684 done
# row 1685 done
# row 1686 done
# row 1687 done
# row 1688 done
# row 1689 done
# row 1690 done
# row 1691 done
# row 1692 done
# row 1693 done
# row 1694 done
# row 1695 done
# row 1696 done
# row 1697 done
# row 1698 done
# row 1699 done
# row 1700 done
# row 1701 done
# row 1702 done
# row 1703 done
# row 1704 done
# row 1705 done
# row 1706 done
# row 1707 done
# row 1708 done
# row 1709 done
# row 1710 done
# row 1711 done
# row 1712 done
# row 1713 done
# row 1714 done
# row 1715 done
# row 1716 done
# row 1717 done
# row 1718 done
# row 1719 done
# row 1720 done
# row 1721 done
# row 1722 done
# row 1723 done
# row 1724 done
# row 1725 done
# row 1726 done
# row 1727 done
# row 1728 done
# row 1729 done
# row 1730 done
# row 1731 done
# row 1732 done
# row 1733 done
# row 1734 done
# row 1735 done
# row 1736 done
# row 1737 done
# row 1738 done
# row 1739 done
# row 1740 done
# row 1741 done
# row 1742 done
# row 1743 done
# row 1744 done
# row 1745 done
# row 1746 done
# row 1747 done
# row 1748 done
# row 1749 done
# row 1750 done
# row 1751 done
# row 1752 done
# row 1753 done
# row 1754 done
# row 1755 done
# row 1756 done
# row 1757 done
# row 1758 done
# row 1759 done
# row 1760 done
# row 1761 done
# row 1762 done
# row 1763 done
# row 1764 done
# row 1765 done
# row 1766 done
# row 1767 done
# row 1768 done
# row 1769 done
# row 1770 done
# row 1771 done
# row 1772 done
# row 1773 done
# row 1774 done
# row 1775 done
# row 1776 done
# row 1777 done
# row 1778 done
# row 1779 done
# row 1780 done
# row 1781 done
# row 1782 done
# row 1783 done
# row 1784 done
# row 1785 done
# row 1786 done
# row 1787 done
# row 1788 done
# row 1789 done
# row 1790 done
# row 1791 done
# row 1792 done
# row 1793 done
# row 1794 done
# row 1795 done
# row 1796 done
# row 1797 done
# row 1798 done
# row 1799 done
# row 1800 done
# row 1801 done
# row 1802 done
# row 1803 done
# row 1804 done
# row 1805 done
# row 1806 done
# row 1807 done
# row 1808 done
# row 1809 done
# row 1810 done
# row 1811 done
# row 1812 done
# row 1813 done
# row 1814 done
# row 1815 done
# row 1816 done
# row 1817 done
# row 1818 done
# row 1819 done
# row 1820 done
# row 1821 done
# row 1822 done
# row 1823 done
# row 1824 done
# row 1825 done
# row 1826 done
# row 1827 done
# row 1828 done
# row 1829 done
# row 1830 done
# row 1831 done
# row 1832 done
# row 1833 done
# row 1834 done
# row 1835 done
# row 1836 done
# row 1837 done
# row 1838 done
# row 1839 done
# row 1840 done
# row 1841 done
# row 1842 done
# row 1843 done
# row 1844 done
# row 1845 done
# row 1846 done
# row 1847 done
# row 1848 done
# row 1849 done
# row 1850 done
# row 1851 done
# row 1852 done
# row 1853 done
# row 1854 done
# row 1855 done
# row 1856 done
# row 1857 done
# row 1858 done
# row 1859 done
# row 1860 done
# row 1861 done
# row 1862 done
# row 1863 done
# row 1864 done
# row 1865 done
# row 1866 done
# row 1867 done
# row 1868 done
# row 1869 done
# row 1870 done
# row 1871 done
# row 1872 done
# row 1873 done
# row 1874 done
# row 1875 done
# row 1876 done
# row 1877 done
# row 1878 done
# row 1879 done
# row 1880 done
# row 1881 done
# row 1882 done
# row 1883 done
# row 1884 done
# row 1885 done
# row 1886 done
# row 1887 done
# row 1888 done
# row 1889 done
# row 1890 done
# row 1891 done
# row 1892 done
# row 1893 done
# row 1894 done
# row 1895 done
# row 1896 done
# row 1897 done
# row 1898 done
# row 1899 done
# row 1900 done
# row 1901 done
# row 1902 done
# row 1903 done
# row 1904 done
# row 1905 done
# row 1906 done
# row 1907 done
# row 1908 done
# row 1909 done
# row 1910 done
# row 1911 done
# row 1912 done
# row 1913 done
# row 1914 done
# row 1915 done
# row 1916 done
# row 1917 done
# row 1918 done
# row 1919 done
# row 1920 done
# row 1921 done
# row 1922 done
# row 1923 done
# row 1924 done
# row 1925 done
# row 1926 done
# row 1927 done
# row 1928 done
# row 1929 done
# row 1930 done
# row 1931 done
# row 1932 done
# row 1933 done
# row 1934 done
# row 1935 done
# row 1936 done
# row 1937 done
# row 1938 done
# row 1939 done
# row 1940 done
# row 1941 done
# row 1942 done
# row 1943 done
# row 1944 done
# row 1945 done
# row 1946 done
# row 1947 done
# row 1948 done
# row 1949 done
# row 1950 done
# row 1951 done
# row 1952 done
# row 1953 done
# row 1954 done
# row 1955 done
# row 1956 done
# row 1957 done
# row 1958 done
# row 1959 done
# row 1960 done
# row 1961 done
# row 1962 done
# row 1963 done
# row 1964 done
# row 1965 done
# row 1966 done
# row 1967 done
# row 1968 done
# row 1969 done
# row 1970 done
# row 1971 done
# row 1972 done
# row 1973 done
# row 1974 done
# row 1975 done
# row 1976 done
# row 1977 done
# row 1978 done
# row 1979 done
# row 1980 done
# row 1981 done
# row 1982 done
# row 1983 done
# row 1984 done
# row 1985 done
# row 1986 done
# row 1987 done
# row 1988 done
# row 1989 done
# row 1990 done
# row 1991 done
# row 1992 done
# row 1993 done
# row 1994 done
# row 1995 done
# row 1996 done
# row 1997 done
# row 1998 done
# row 1999 done
# row 2000 done
# row 2001 done
# row 2002 done
# row 2003 done
# row 2004 done
# row 2005 done
# row 2006 done
# row 2007 done
# row 2008 done
# row 2009 done
# row 2010 done
# row 2011 done
# row 2012 done
# row 2013 done
# row 2014 done
# row 2015 done
# row 2016 done
# row 2017 done
# row 2018 done
# row 2019 done
# row 2020 done
# row 2021 done
# row 2022 done
# row 2023 done
# row 2024 done
# row 2025 done
# row 2026 done
# row 2027 done
# row 2028 done
# row 2029 done
# row 2030 done
# row 2031 done
# row 2032 done
# row 2033 done
# row 2034 done
# row 2035 done
# row 2036 done
# row 2037 done
# row 2038 done
# row 2039 done
# row 2040 done
# row 2041 done
# row 2042 done
# row 2043 done
# row 2044 done
# row 2045 done
# row 2046 done
# row 2047 done
# row 2048 done
# row 2049 done
# row 2050 done
# row 2051 done
# row 2052 done
# row 2053 done
# row 2054 done
# row 2055 done
# row 2056 done
# row 2057 done
# row 2058 done
# row 2059 done
# row 2060 done
# row 2061 done
# row 2062 done
# row 2063 done
# row 2064 done
# row 2065 done
# row 2066 done
# row 2067 done
# row 2068 done
# row 2069 done
# row 2070 done
# row 2071 done
# row 2072 done
# row 2073 done
# row 2074 done
# row 2075 done
# row 2076 done
# row 2077 done
# row 2078 done
# row 2079 done
# row 2080 done
# row 2081 done
# row 2082 done
# row 2083 done
# row 2084 done
# row 2085 done
# row 2086 done
# row 2087 done
# row 2088 done
# row 2089 done
# row 2090 done
# row 2091 done
# row 2092 done
# row 2093 done
# row 2094 done
# row 2095 done
# row 2096 done
# row 2097 done
# row 2098 done
# row 2099 done
# row 2100 done
# row 2101 done
# row 2102 done
# row 2103 done
# row 2104 done
# row 2105 done
# row 2106 done
# row 2107 done
# row 2108 done
# row 2109 done
# row 2110 done
# row 2111 done
# row 2112 done
# row 2113 done
# row 2114 done
# row 2115 done
# row 2116 done
# row 2117 done
# row 2118 done
# row 2119 done
# row 2120 done
# row 2121 done
# row 2122 done
# row 2123 done
# row 2124 done
# row 2125 done
# row 2126 done
# row 2127 done
# row 2128 done
# row 2129 done
# row 2130 done
# row 2131 done
# row 2132 done
# row 2133 done
# row 2134 done
# row 2135 done
# row 2136 done
# row 2137 done
# row 2138 done
# row 2139 done
# row 2140 done
# row 2141 done
# row 2142 done
# row 2143 done
# row 2144 done
# row 2145 done
# row 2146 done
# row 2147 done
# row 2148 done
# row 2149 done
# row 2150 done
# row 2151 done
# row 2152 done
# row 2153 done
# row 2154 done
# row 2155 done
# row 2156 done
# row 2157 done
# row 2158 done
# row 2159 done
# row 2160 done
# row 2161 done
# row 2162 done
# row 2163 done
# row 2164 done
# row 2165 done
# row 2166 done
# row 2167 done
# row 2168 done
# row 2169 done
# row 2170 done
# row 2171 done
# row 2172 done
# row 2173 done
# row 2174 done
# row 2175 done
# row 2176 done
# row 2177 done
# row 2178 done
# row 2179 done
# row 2180 done
# row 2181 done
# row 2182 done
# row 2183 done
# row 2184 done
# row 2185 done
# row 2186 done
# row 2187 done
# row 2188 done
# row 2189 done
# row 2190 done
# row 2191 done
# row 2192 done
# row 2193 done
# row 2194 done
# row 2195 done
# row 2196 done
# row 2197 done
# row 2198 done
# row 2199 done
# row 2200 done
# row 2201 done
# row 2202 done
# row 2203 done
# row 2204 done
# row 2205 done
# row 2206 done
# row 2207 done
# row 2208 done
# row 2209 done
# row 2210 done
# row 2211 done
# row 2212 done
# row 2213 done
# row 2214 done
# row 2215 done
# row 2216 done
# row 2217 done
# row 2218 done
# row 2219 done
# row 2220 done
# row 2221 done
# row 2222 done
# row 2223 done
# row 2224 done
# row 2225 done
# row 2226 done
# row 2227 done
# row 2228 done
# row 2229 done
# row 2230 done
# row 2231 done
# row 2232 done
# row 2233 done
# row 2234 done
# row 2235 done
# row 2236 done
# row 2237 done
# row 2238 done
# row 2239 done
# row 2240 done
# row 2241 done
# row 2242 done
# row 2243 done
# row 2244 done
# row 2245 done
# row 2246 done
# row 2247 done
# row 2248 done
# row 2249 done
# row 2250 done
# row 2251 done
# row 2252 done
# row 2253 done
# row 2254 done
# row 2255 done
# row 2256 done
# row 2257 done
# row 2258 done
# row 2259 done
# row 2260 done
# row 2261 done
# row 2262 done
# row 2263 done
# row 2264 done
# row 2265 done
# row 2266 done
# row 2267 done
# row 2268 done
# row 2269 done
# row 2270 done
# row 2271 done
# row 2272 done
# row 2273 done
# row 2274 done
# row 2275 done
# row 2276 done
# row 2277 done
# row 2278 done
# row 2279 done
# row 2280 done
# row 2281 done
# row 2282 done
# row 2283 done
# row 2284 done
# row 2285 done
# row 2286 done
# row 2287 done
# row 2288 done
# row 2289 done
# row 2290 done
# row 2291 done
# row 2292 done
# row 2293 done
# row 2294 done
# row 2295 done
# row 2296 done
# row 2297 done
# row 2298 done
# row 2299 done
# row 2300 done
# row 2301 done
# row 2302 done
# row 2303 done
# row 2304 done
# row 2305 done
# row 2306 done
# row 2307 done
# row 2308 done
# row 2309 done
# row 2310 done
# row 2311 done
# row 2312 done
# row 2313 done
# row 2314 done
# row 2315 done
# row 2316 done
# row 2317 done
# row 2318 done
# row 2319 done
# row 2320 done
# row 2321 done
# row 2322 done
# row 2323 done
# row 2324 done
# row 2325 done
# row 2326 done
# row 2327 done
# row 2328 done
# row 2329 done
# row 2330 done
# row 2331 done
# row 2332 done
# row 2333 done
# row 2334 done
# row 2335 done
# row 2336 done
# row 2337 done
# row 2338 done
# row 2339 done
# row 2340 done
# row 2341 done
# row 2342 done
# row 2343 done
# row 2344 done
# row 2345 done
# row 2346 done
# row 2347 done
# row 2348 done
# row 2349 done
# row 2350 done
# row 2351 done
# row 2352 done
# row 2353 done
# row 2354 done
# row 2355 done
# row 2356 done
# row 2357 done
# row 2358 done
# row 2359 done
# row 2360 done
# row 2361 done
# row 2362 done
# row 2363 done
# row 2364 done
# row 2365 done
# row 2366 done
# row 2367 done
# row 2368 done
# row 2369 done
# row 2370 done
# row 2371 done
# row 2372 done
# row 2373 done
# row 2374 done
# row 2375 done
# row 2376 done
# row 2377 done
# row 2378 done
# row 2379 done
# row 2380 done
# row 2381 done
# row 2382 done
# row 2383 done
# row 2384 done
# row 2385 done
# row 2386 done
# row 2387 done
# row 2388 done
# row 2389 done
# row 2390 done
# row 2391 done
# row 2392 done
# row 2393 done
# row 2394 done
# row 2395 done
# row 2396 done
# row 2397 done
# row 2398 done
# row 2399 done
# row 2400 done
# row 2401 done
# row 2402 done
# row 2403 done
# row 2404 done
# row 2405 done
# row 2406 done
# row 2407 done
# row 2408 done
# row 2409 done
# row 2410 done
# row 2411 done
# row 2412 done
# row 2413 done
# row 2414 done
# row 2415 done
# row 2416 done
# row 2417 done
# row 2418 done
# row 2419 done
# row 2420 done
# row 2421 done
# row 2422 done
# row 2423 done
# row 2424 done
# row 2425 done
# row 2426 done
# row 2427 done
# row 2428 done
# row 2429 done
# row 2430 done
# row 2431 done
# row 2432 done
# row 2433 done
# row 2434 done
# row 2435 done
# row 2436 done
# row 2437 done
# row 2438 done
# row 2439 done
# row 2440 done
# row 2441 done
# row 2442 done
# row 2443 done
# row 2444 done
# row 2445 done
# row 2446 done
# row 2447 done
# row 2448 done
# row 2449 done
# row 2450 done
# row 2451 done
# row 2452 done
# row 2453 done
# row 2454 done
# row 2455 done
# row 2456 done
# row 2457 done
# row 2458 done
# row 2459 done
# row 2460 done
# row 2461 done
# row 2462 done
# row 2463 done
# row 2464 done
# row 2465 done
# row 2466 done
# row 2467 done
# row 2468 done
# row 2469 done
# row 2470 done
# row 2471 done
# row 2472 done
# row 2473 done
# row 2474 done
# row 2475 done
# row 2476 done
# row 2477 done
# row 2478 done
# row 2479 done
# row 2480 done
# row 2481 done
# row 2482 done
# row 2483 done
# row 2484 done
# row 2485 done
# row 2486 done
# row 2487 done
# row 2488 done
# row 2489 done
# row 2490 done
# row 2491 done
# row 2492 done
# row 2493 done
# row 2494 done
# row 2495 done
# row 2496 done
# row 2497 done
# row 2498 done
# row 2499 done
# row 2500 done
# row 2501 done
# row 2502 done
# row 2503 done
# row 2504 done
# row 2505 done
# row 2506 done
# row 2507 done
# row 2508 done
# row 2509 done
# row 2510 done
# row 2511 done
# row 2512 done
# row 2513 done
# row 2514 done
# row 2515 done
# row 2516 done
# row 2517 done
# row 2518 done
# row 2519 done
# row 2520 done
# row 2521 done
# row 2522 done
# row 2523 done
# row 2524 done
# row 2525 done
# row 2526 done
# row 2527 done
# row 2528 done
# row 2529 done
# row 2530 done
# row 2531 done
# row 2532 done
# row 2533 done
# row 2534 done
# row 2535 done
# row 2536 done
# row 2537 done
# row 2538 done
# row 2539 done
# row 2540 done
# row 2541 done
# row 2542 done
# row 2543 done
# row 2544 done
# row 2545 done
# row 2546 done
# row 2547 done
# row 2548 done
# row 2549 done
# row 2550 done
# row 2551 done
# row 2552 done
# row 2553 done
# row 2554 done
# row 2555 done
# row 2556 done
# row 2557 done
# row 2558 done
# row 2559 done
# row 2560 done
# row 2561 done
# row 2562 done
# row 2563 done
# row 2564 done
# row 2565 done
# row 2566 done
# row 2567 done
# row 2568 done
# row 2569 done
# row 2570 done
# row 2571 done
# row 2572 done
# row 2573 done
# row 2574 done
# row 2575 done
# row 2576 done
# row 2577 done
# row 2578 done
# row 2579 done
# row 2580 done
# row 2581 done
# row 2582 done
# row 2583 done
# row 2584 done
# row 2585 done
# row 2586 done
# row 2587 done
# row 2588 done
# row 2589 done
# row 2590 done
# row 2591 done
# row 2592 done
# row 2593 done
# row 2594 done
# row 2595 done
# row 2596 done
# row 2597 done
# row 2598 done
# row 2599 done
# row 2600 done
# row 2601 done
# row 2602 done
# row 2603 done
# row 2604 done
# row 2605 done
# row 2606 done
# row 2607 done
# row 2608 done
# row 2609 done
# row 2610 done
# row 2611 done
# row 2612 done
# row 2613 done
# row 2614 done
# row 2615 done
# row 2616 done
# row 2617 done
# row 2618 done
# row 2619 done
# row 2620 done
# row 2621 done
# row 2622 done
# row 2623 done
# row 2624 done
# row 2625 done
# row 2626 done
# row 2627 done
# row 2628 done
# row 2629 done
# row 2630 done
# row 2631 done
# row 2632 done
# row 2633 done
# row 2634 done
# row 2635 done
# row 2636 done
# row 2637 done
# row 2638 done
# row 2639 done
# row 2640 done
# row 2641 done
# row 2642 done
# row 2643 done
# row 2644 done
# row 2645 done
# row 2646 done
# row 2647 done
# row 2648 done
# row 2649 done
# row 2650 done
# row 2651 done
# row 2652 done
# row 2653 done
# row 2654 done
# row 2655 done
# row 2656 done
# row 2657 done
# row 2658 done
# row 2659 done
# row 2660 done
# row 2661 done
# row 2662 done
# row 2663 done
# row 2664 done
# row 2665 done
# row 2666 done
# row 2667 done
# row 2668 done
# row 2669 done
# row 2670 done
# row 2671 done
# row 2672 done
# row 2673 done
# row 2674 done
# row 2680 done
# row 2681 done
# row 2682 done
# row 2683 done
# row 2684 done
# row 2685 done
# row 2686 done
# row 2687 done
# row 2688 done
# row 2689 done
# row 2690 done
# row 2691 done
# row 2692 done
# row 2693 done
# row 2694 done
# row 2695 done
# row 2696 done
# row 2697 done
# row 2698 done
# row 2699 done
# row 2700 done
# row 2701 done
# row 2702 done
# row 2703 done
# row 2704 done
# row 2705 done
# row 2706 done
# row 2707 done
# row 2708 done
# row 2709 done
# row 2710 done
# row 2711 done
# row 2712 done
# row 2713 done
# row 2714 done
# row 2715 done
# row 2716 done
# row 2717 done
# row 2718 done
# row 2719 done
# row 2720 done
# row 2721 done
# row 2722 done
# row 2723 done
# row 2724 done
# row 2725 done
# row 2726 done
# row 2727 done
# row 2728 done
# row 2729 done
# row 2730 done
# row 2731 done
# row 2732 done
# row 2733 done
# row 2734 done
# row 2735 done
# row 2736 done
# row 2737 done
# row 2738 done
# row 2739 done
# row 2740 done
# row 2741 done
# row 2742 done
# row 2743 done
# row 2744 done
# row 2745 done
# row 2746 done
# row 2747 done
# row 2748 done
# row 2749 done
# row 2750 done
# row 2751 done
# row 2752 done
# row 2753 done
# row 2754 done
# row 2755 done
# row 2756 done
# row 2757 done
# row 2758 done
# row 2759 done
# row 2760 done
# row 2761 done
# row 2762 done
# row 2763 done
# row 2764 done
# row 2765 done
# row 2766 done
# row 2767 done
# row 2768 done
# row 2769 done
# row 2770 done
# row 2771 done
# row 2772 done
# row 2773 done
# row 2774 done
# row 2775 done
# row 2776 done
# row 2777 done
# row 2778 done
# row 2779 done
# row 2780 done
# error in row 2781: Sub-geometries may have coordinate sequences, but multi-part geometries do not
# error in row 2782: Sub-geometries may have coordinate sequences, but multi-part geometries do not
# row 2783 done
# row 2784 done
# row 2785 done
# row 2786 done
# row 2787 done
# row 2788 done
# row 2789 done
# row 2790 done
# row 2791 done
# row 2792 done
# row 2793 done
# row 2794 done
# row 2795 done
# row 2796 done
# row 2797 done
# row 2798 done
# row 2799 done
# row 2800 done
# row 2801 done
# row 2802 done
# row 2803 done
# error in row 2804: Sub-geometries may have coordinate sequences, but multi-part geometries do not
# row 2805 done
# row 2806 done
# row 2807 done
# row 2808 done
# row 2809 done
# row 2810 done
# row 2811 done
# row 2812 done
# row 2813 done
# row 2814 done
# row 2815 done
# row 2816 done
# row 2817 done
# row 2818 done
# row 2819 done
# row 2820 done
# row 2821 done
# row 2822 done
# row 2823 done
# row 2824 done
# row 2825 done
# row 2826 done
# row 2827 done
# row 2828 done
# row 2829 done
# row 2830 done
# row 2831 done
# row 2832 done
# row 2833 done
# row 2834 done
# row 2835 done
# row 2836 done
# row 2837 done
# row 2838 done
# row 2839 done
# row 2840 done
# row 2841 done
# row 2842 done
# error in row 2843: Sub-geometries may have coordinate sequences, but multi-part geometries do not
# row 2844 done
# row 2845 done
# row 2846 done
# row 2847 done
# row 2848 done
# row 2849 done
# row 2850 done
# row 2851 done
# row 2852 done
# row 2853 done
# row 2854 done
# row 2855 done
# row 2856 done
# row 2857 done
# row 2858 done
# row 2859 done
# row 2860 done
# row 2861 done
# row 2862 done
# row 2863 done
# row 2864 done
# row 2865 done
# row 2866 done
# row 2867 done
# row 2868 done
# row 2869 done
# row 2870 done
# row 2871 done
# row 2872 done
# row 2873 done
# row 2874 done
# row 2875 done
# row 2876 done
# row 2877 done
# row 2878 done
# row 2879 done
# row 2880 done
# row 2881 done
# row 2882 done
# row 2883 done
# row 2884 done
# row 2885 done
# row 2886 done
# row 2887 done
# row 2888 done
# row 2889 done
# row 2890 done
# row 2891 done
# row 2892 done
# row 2893 done
# row 2894 done
# row 2895 done
# row 2896 done
# row 2897 done
# row 2898 done
# row 2899 done
# row 2900 done
# row 2901 done
# row 2902 done
# row 2903 done
# row 2904 done
# row 2905 done
# row 2906 done
# row 2907 done
# row 2908 done
# row 2909 done
# row 2910 done
# row 2911 done
# row 2912 done
# row 2913 done
# row 2914 done
# row 2915 done
# row 2916 done
# row 2917 done
# row 2918 done
# row 2919 done
# row 2920 done
# row 2921 done
# row 2922 done
# row 2923 done
# row 2924 done
# row 2925 done
# row 2926 done
# row 2927 done
# row 2928 done
# row 2929 done
# row 2930 done
# row 2931 done
# row 2932 done
# row 2933 done
# row 2934 done
# row 2935 done
# row 2936 done
# row 2937 done
# row 2938 done
# row 2939 done
# row 2940 done
# row 2941 done
# row 2942 done
# row 2943 done
# row 2944 done
# error in row 2945: Sub-geometries may have coordinate sequences, but multi-part geometries do not
# row 2946 done
# row 2947 done
# row 2948 done
# row 2949 done
# row 2950 done
# row 2951 done
# row 2952 done
# row 2953 done
# row 2954 done
# row 2955 done
# row 2956 done
# row 2957 done
# row 2958 done
# row 2959 done
# row 2960 done
# row 2961 done
# row 2962 done
# row 2963 done
# row 2964 done
# row 2965 done
# row 2966 done
# row 2967 done
# row 2968 done
# row 2969 done
# row 2970 done
# row 2971 done
# row 2972 done
# row 2973 done
# row 2974 done
# row 2975 done
# row 2976 done
# row 2977 done
# row 2978 done
# row 2979 done
# row 2980 done
# row 2981 done
# row 2982 done
# row 2983 done
# row 2984 done
# row 2985 done
# row 2986 done
# row 2987 done
# row 2988 done
# error in row 2989: Sub-geometries may have coordinate sequences, but multi-part geometries do not
# row 2990 done
# row 2991 done
# row 2992 done
# row 2993 done
# row 2994 done
# row 2995 done
# row 2996 done
# row 2997 done
# row 2998 done
# row 2999 done
# row 3000 done
# row 3001 done
# row 3002 done
# row 3003 done
# error in row 3004: Sub-geometries may have coordinate sequences, but multi-part geometries do not
# row 3005 done
# row 3006 done
# row 3007 done
# row 3008 done
# row 3009 done
# row 3010 done
# row 3011 done
# row 3012 done
# row 3013 done
# error in row 3014: Sub-geometries may have coordinate sequences, but multi-part geometries do not
# row 3015 done
# row 3016 done
# row 3017 done
# row 3018 done
# row 3019 done
# row 3020 done
# row 3021 done
# error in row 3022: Sub-geometries may have coordinate sequences, but multi-part geometries do not
# row 3023 done
# row 3024 done
# row 3025 done
# row 3026 done
# row 3027 done
# row 3028 done
# row 3029 done
# row 3030 done
# row 3031 done
# row 3032 done
# row 3033 done
# row 3034 done
# row 3035 done
# row 3036 done
# row 3037 done
# row 3038 done
# row 3039 done
# row 3040 done
# row 3041 done
# row 3042 done
# row 3043 done
# row 3044 done
# row 3045 done
# row 3046 done
# row 3047 done
# row 3048 done
# row 3049 done
# row 3050 done
# row 3051 done
# row 3052 done
# row 3053 done
# row 3054 done
# row 3055 done
# row 3056 done
# row 3057 done
# row 3058 done
# row 3059 done
# row 3060 done
# row 3061 done
# row 3062 done
# row 3063 done
# row 3064 done
# row 3065 done
# row 3066 done
# row 3067 done
# row 3068 done
# row 3069 done
# row 3070 done
# row 3071 done
# row 3072 done
# row 3073 done
# row 3074 done
# row 3075 done
# row 3076 done
# row 3077 done
# row 3078 done
# row 3079 done
# row 3080 done
# row 3081 done
# row 3082 done
# row 3083 done
# row 3084 done
# row 3085 done
# row 3086 done
# row 3087 done
# row 3088 done
# row 3089 done
# row 3090 done
# row 3091 done
# row 3092 done
# row 3093 done
# row 3094 done
# row 3095 done
# row 3096 done
# row 3097 done
# row 3098 done
# row 3099 done
# row 3100 done
# row 3101 done
# row 3102 done
# row 3103 done
# row 3104 done
# row 3105 done
# row 3106 done
# row 3107 done
# row 3108 done
# row 3109 done
# row 3110 done
# row 3111 done
# row 3112 done
# row 3113 done
# row 3114 done
# row 3115 done
# row 3116 done
# row 3117 done
# row 3118 done
# row 3119 done
# row 3120 done
# row 3121 done
# row 3122 done
# row 3123 done
# row 3124 done
# row 3125 done
# row 3126 done
# row 3127 done
# row 3128 done
# row 3129 done
# row 3130 done
# row 3131 done
# row 3132 done
# row 3133 done
# row 3134 done
# row 3135 done
# row 3136 done
# row 3137 done
# row 3138 done
# row 3139 done
# row 3140 done
# row 3141 done
# row 3142 done
# row 3143 done
# row 3144 done
# row 3145 done
# row 3146 done
# row 3147 done
# row 3148 done
# row 3149 done
# row 3150 done
# row 3151 done
# row 3152 done
# row 3153 done
# row 3154 done
# row 3155 done
# row 3156 done
# row 3157 done
# row 3158 done
# row 3159 done
# row 3160 done
# row 3161 done
# row 3162 done
# row 3163 done
# row 3164 done
# row 3165 done
# row 3166 done
# row 3167 done
# row 3168 done
# row 3169 done
# row 3170 done
# row 3171 done
# row 3172 done
# row 3173 done
# row 3174 done
# row 3175 done
# row 3176 done
# row 3177 done
# row 3178 done
# row 3179 done
# row 3180 done
# row 3181 done
# row 3182 done
# row 3183 done
# row 3184 done
# row 3185 done
# row 3186 done
# row 3187 done
# row 3188 done
# row 3189 done
# row 3190 done
# row 3191 done
# row 3192 done
# row 3193 done
# row 3194 done
# row 3195 done
# row 3196 done
# row 3197 done
# row 3198 done
# row 3199 done
# row 3200 done
# row 3201 done
# row 3202 done
# row 3203 done
# row 3204 done
# row 3205 done
# row 3206 done
# row 3207 done
# row 3208 done
# row 3209 done
# row 3210 done
# row 3211 done
# row 3212 done
# row 3213 done
# row 3214 done
# row 3215 done
# row 3216 done
# row 3217 done
# row 3218 done
# row 3219 done
# row 3220 done
# row 3221 done
# row 3222 done
# row 3223 done
# row 3224 done
# row 3225 done
# row 3226 done
# row 3227 done
# row 3228 done
# row 3231 done
# row 3232 done
# row 3233 done
# row 3234 done
# row 3235 done
# row 3236 done
# row 3237 done
# row 3238 done
# row 3239 done
# row 3240 done
# row 3241 done
# row 3242 done
# row 3243 done

# %% [markdown]
# This is the merging of the bike lanes to the census tracts they belong to -- it's in a separate code block so I can run it every time I import data from the beginning while avoiding the API calls.

# %%
import pandas as pd

data = pd.read_csv(data_path + 'census_tracts.txt', header=None)
df['census'] = data
df.head()
# Out:
#    FID                        STREET_NAM  ROADINVENT  FUNCTIONAL JURISDICTI  \
# 0    1  Veterans Of Foreign Wars Parkway     6212500           2          3
# 1    2  Veterans Of Foreign Wars Parkway     4847800           2          3
# 2    3  Veterans Of Foreign Wars Parkway     4838800           2          3
# 3    4                       Lake Street     4547801           6          2
# 4    5               Commonwealth Avenue     5141000           3          2
#
#    Divided InstallDat ExisFacil  Shape_Leng  Shape__Length  \
# 0        1       2013        BL  175.249590     175.249590
# 1        1       2013        BL   82.501161      82.501161
# 2        1       2013        BL   81.227024      81.227024
# 3        0       2010       SLM  137.040790     137.040790
# 4        1       2013       SLM  213.655205     213.655205
#
#                                             geometry   census
# 0  LINESTRING (-71.16828 42.29067, -71.16840 42.2...  1301.01
# 1  LINESTRING (-71.16811 42.29049, -71.16777 42.2...  1301.01
# 2  LINESTRING (-71.16656 42.29131, -71.16574 42.2...  1301.01
# 3  LINESTRING (-71.16612 42.34068, -71.16611 42.3...     3.02
# 4  LINESTRING (-71.16612 42.33996, -71.16554 42.3...     5.02

# %% [markdown]
# We will also import the area of each census tract's landmass. This will allow us to scale certain features to the landmass of a given census tract, since larger tracts may have more bike lanes than smaller ones, etc.

# %%
path_to_shapefile = data_path + 'tract_areas.zip'

gdf = gpd.read_file(path_to_shapefile)

gdf = gdf.to_crs(epsg=2249)

gdf['area_sq_m'] = gdf.geometry.area
gdf['area_sq_km'] = gdf['area_sq_m'] / 10**6

gdf = gdf[['NAME', 'area_sq_km', 'area_sq_m']]
print(gdf.head())
# Out:
#       NAME  area_sq_km     area_sq_m
# 0  3362.02   11.378181  1.137818e+07
# 1  3301.02  106.036769  1.060368e+08
# 2  3391.01    9.590139  9.590139e+06
# 3  3567.03   16.263195  1.626319e+07
# 4  3302.02   83.121202  8.312120e+07

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# We will now engineer two features: **Bikelane Frequency and Bikelane Connectivity**.
#
# **Bikelane Frequency** is calculated by summing the lengths of all bike lanes in a given census tract and dividing this sum by the area of the census tract -- it's basically the proportion of a census tract that is made up of bike lanes. It will give less priority to tracts with less roads (as it should -- this should mean that less commuters bike in those tracts) and large tracts with few bike lanes.\
# I have experimented with a few ways to collect this. A previous attempt relied on adding up the number of unique streets that contained bike lanes in a given tract, weighting them by the manual weights assigned at the start. This ended up being an inaccurate way of processing data, as it does not take into account the length of the bike lane, and a bike lane that spans multiple short streets would be given an unfairly high weight. This code is commented out.
#
# **Bikelane Connectivity** is what we wanted to focus on for this insight. It is calculated by first finding the census tracts that each bike lane street run through. The "Connectivity Degree" of a street would then be calculated by adding up the Bikelane Frequency of each of the tracts that the lane runs through. Finally, the connectivity of each tract would be the sum of each of the "Connectivity Degrees" of all bike lanes in the tract divided by the square of the tract's area -- again, to account for larger tracts naturally having more bike lanes than smaller ones, and thus unfairly having far more opportunities of connectivity.
#
# These features would later be plotted against the bike usage of each tract to observe trends (if there are any).

# %%
import math

# testing frequency
census_bikelane_freq = {}

# old ineffective method
# for _, row in df.iterrows():
#     if math.isnan(float(row['census'])):
#         continue
#     if row['census'] not in census_bikelane_freq:
#         census_bikelane_freq[row['census']] = [row['STREET_NAM'] for _ in range(weights[row['ExisFacil']])]
#     else:
#         if row['STREET_NAM'] not in census_bikelane_freq[row['census']]:
#             w = weights[row['ExisFacil']] if row['ExisFacil'] in weights else 1
#             census_bikelane_freq[row['census']].append([row['STREET_NAM'] for _ in range(w)]) 

# for key in census_bikelane_freq:
#     census_bikelane_freq[key] = len(census_bikelane_freq[key]) ** 2

# for every street, add its length to the census tract key it belongs in
for _, row in df.iterrows():
    if math.isnan(float(row['census'])):
        continue
    if row['census'] not in census_bikelane_freq:
        census_bikelane_freq[row['census']] = row['Shape_Leng']
    else:
        census_bikelane_freq[row['census']] += row['Shape_Leng']

# divide every census tract frequency value by the area of its landmass. if such area does not exist, delete the tract
exists = []
for key in census_bikelane_freq:
    if str(key) in gdf['NAME'].values:
        census_bikelane_freq[key] /= gdf.loc[gdf['NAME'] == str(key)]['area_sq_km'].values[0]# ** 2
    else:
        exists.append(key)
    
for key in exists:
    del census_bikelane_freq[key]

# testing connectivity

# add every tract that a street spans to a street key 
tract_span_street = {}
for _, row in df.iterrows():
    if row['STREET_NAM'] not in tract_span_street:
        tract_span_street[row['STREET_NAM']] = [row['census']]
    else:
        if row['census'] not in tract_span_street[row['STREET_NAM']]:
            tract_span_street[row['STREET_NAM']].append(row['census'])

census_bikelane_connectivity = {}

# for every street, look at the census tracts it spans and add the resulting frequency value we assigned
# that tract earlier to a sum called "degree". then, add this degree to every tract that this street belongs
# to via census tract key in a dict
for street in tract_span_street:
    degree = 0
    censuses = []
    for census in tract_span_street[street]:
        if census in census_bikelane_freq:
            degree += census_bikelane_freq[census]
            censuses.append(census)
    tract_span_street[street] = degree
    for census in censuses:
        if census not in census_bikelane_connectivity:
            census_bikelane_connectivity[census] = degree
        else:
            census_bikelane_connectivity[census] += degree

# once again divide each census' value by its landmass and delete ineligible tracts.
exists = []
for key in census_bikelane_connectivity:
    if str(key) in gdf['NAME'].values:
        census_bikelane_connectivity[key] /= gdf.loc[gdf['NAME'] == str(key)]['area_sq_km'].values[0] ** 2
    else:
        exists.append(key)
    
for key in exists:
    del census_bikelane_connectivity[key]

print(census_bikelane_connectivity)
print(census_bikelane_freq)
# print(census_bikelane_freq.keys())
# Out:
# {1301.01: 125.28653535278752, 3.02: 1263.5313565683912, 2.01: 3557.457580532943, 5.02: 853.078366916583, 8.06: 657.173674146557, 2.02: 3260.6213517879705, 910.01: 308.3133620205759, 9812.01: 202.77790668122995, 1006.03: 850.4755060957211, 606.04: 747.2350729819951, 501.01: 2197.6623144224122, 1.02: 1083.1742799176207, 509.01: 329.3613003490028, 4.02: 1054.077675076013, 1106.07: 997.034439082545, 606.03: 5885.131944769883, 1304.02: 164.04331157739912, 909.01: 583.2494004895009, 511.01: 137.87457122000438, 3.01: 1289.312724104007, 4012.01: 8.13126534154911, 303.02: 6330.702441373761, 303.01: 1811.702376225066, 1401.07: 1946.076800422745, 1104.01: 1720.4128002615157, 8.04: 3651.687417847147, 1011.01: 1362.3303604358182, 813.02: 6620.63363894401, 104.03: 31025.92909564289, 6.01: 4846.0611517368225, 1103.01: 815.6883113595634, 1201.05: 298.6368405868446, 808.01: 3006.474719687914, 104.04: 26276.16008894313, 806.01: 3839.4911769401806, 108.02: 49043.52737531766, 1402.02: 208.45535125434495, 7.03: 42143.634876953474, 1011.02: 2919.338043742362, 104.05: 8595.335207198521, 811.01: 29061.724570743525, 1101.05: 7097.445233802812, 102.05: 20727.65896213665, 1101.04: 11299.135758841772, 1.01: 8640.043441263477, 1010.02: 698.9393937512813, 810.01: 1982.175049853638, 804.01: 4047.8710612769337, 709.01: 197513.12539659944, 711.01: 6689.508048847525, 1010.01: 553.5980279524949, 203.05: 5483.780211856523, 203.01: 19024.943061543432, 606.02: 637.030670314065, 107.01: 21157.284638471392, 1201.04: 5297.500868381274, 108.01: 37343.489941155494, 612.04: 4445.688013929719, 701.04: 2531.7205000171216, 4.01: 3156.1050950563067, 201.01: 7328.892989009503, 1105.01: 1639.6158752287888, 101.04: 11308.314961923146, 8.05: 5199.401396242352, 1202.01: 2281.839565080036, 1203.01: 1688.4009170680326, 612.03: 6198.537218009263, 1106.01: 460.97826056224477, 606.01: 19076.783164752112, 6.04: 6472.5436980903905, 703.02: 13439.786043905011, 612.01: 2031.2573339180622, 5.05: 15508.072526772368, 7.01: 7718.604543489547, 102.04: 22269.441701802094, 705.01: 43789.099603113245, 712.01: 4440.94423913287, 921.01: 476.5721789236023, 1201.03: 7015.878062862083, 8.07: 13148.359616933247, 708.02: 18497.718703137572, 1401.02: 49.15513187188422, 101.03: 10746.963105884484, 107.02: 10643.690412004229, 9815.01: 189.24017215896947, 3739.01: 18.402300146386082, 811.02: 1347.0826881063049, 408.01: 162.9891842326898, 1102.01: 4822.050581385478, 9812.02: 45.03551415393572, 6.03: 1368.9435444843573, 5.03: 14759.328076783806, 5.06: 2258.158901461453, 7.04: 3844.812127836442, 1105.02: 956.4583670958043, 702.02: 27415.003919581493, 102.06: 0.06436133938114076, 702.01: 58955.96559443525, 1006.01: 1037.3275457622462, 709.02: 28372.657394427424, 708.01: 105139.21262613904, 701.02: 50046.805079256505, 404.01: 3065.456182602864, 705.02: 9622.55781817495, 813.01: 1978.2151131488217, 1402.01: 87.46156088407915, 3501.06: 214.4572762801372, 3531.02: 46.28091985743434, 703.01: 7471.246378134995, 612.02: 1203.5300716425127, 203.02: 21258.916063327848, 203.04: 10295.566855373518, 704.02: 3796.6458547759316, 611.01: 1711.3579235094903, 9801.01: 0.5313647116312312, 3521.01: 117.82113944954315}
# {1301.01: 118.57503196625993, 3.02: 254.19027622725005, 5.02: 284.1440413940628, 3.01: 199.06489225068293, 2.01: 597.9947102971255, 2.02: 557.6177128703736, 1304.02: 89.01373075296439, 4.02: 196.4318392916069, 8.06: 240.72490800947557, 6.01: 362.8842624119073, 1106.01: 207.06768183708138, 1.02: 213.59722297907504, 1201.05: 124.49273381251388, 8.04: 740.872589338708, 8.05: 337.1443659207243, 7.04: 164.0195653781856, 1.01: 275.87397493226007, 1401.07: 96.67174084993313, 1104.01: 151.11259259584784, 1101.04: 702.2235522102985, 811.01: 434.3050502973466, 811.02: 179.72048651850122, 8.07: 600.5349438360397, 1106.07: 325.89452975532464, 7.03: 1252.1523708661136, 1102.01: 398.7315224129137, 9815.01: 606.056419341634, 1103.01: 84.75571116657527, 1201.04: 594.292660724731, 1202.01: 559.19387598307, 1201.03: 541.6136904521926, 1101.05: 485.7667410141216, 810.01: 218.98457808296405, 1010.01: 166.4562716648708, 1011.02: 507.3362297020202, 1011.01: 213.94680223910038, 102.04: 1570.76847123856, 101.03: 635.7210132283169, 813.02: 647.3705412947198, 806.01: 655.8068666219688, 104.05: 554.7272573476487, 104.03: 350.197845049256, 101.04: 787.8010367382534, 108.02: 1067.2659424443673, 107.01: 853.2271744159475, 1203.01: 226.487308697965, 813.01: 101.98419032822491, 102.05: 264.4863184641426, 1010.02: 189.66793840609753, 804.01: 505.684703443875, 708.01: 877.7801195158457, 709.02: 396.4435395561209, 107.02: 638.8354779198783, 108.01: 670.118670249156, 709.01: 1288.3103608569622, 705.02: 562.3126380998299, 705.01: 681.9344034018761, 712.01: 336.19565201571703, 711.01: 576.1404681894506, 702.02: 1146.1944570405026, 703.02: 337.0955715676647, 404.01: 995.2163152254839, 702.01: 1586.5550052062183, 203.01: 2457.5646993778755, 201.01: 56.9213165177813, 704.02: 193.9833952620614, 701.02: 1546.5940864471668, 910.01: 81.64998242862187, 606.03: 265.1065495399018, 509.01: 108.27436418170896, 612.01: 186.2875572618486, 612.03: 469.53367633293414, 701.04: 800.7111212059617, 303.02: 1400.2102294292374, 1006.01: 86.04210922416371, 921.01: 133.78782098294678, 9812.01: 339.5379299526842, 612.04: 532.1533012675208, 606.04: 351.2098063364071, 909.01: 543.7789710778603, 1006.03: 485.6732405649894, 501.01: 389.3372305764069, 3739.01: 7.906057724806634, 4.01: 260.47266476671854, 1105.01: 99.57034736840782, 5.03: 277.6213827741046, 1105.02: 84.78048585536013, 1402.02: 18.06659725926695, 808.01: 295.04449051489036, 104.04: 252.18616261041865, 708.02: 140.2123951619993, 203.02: 216.6980673430978, 511.01: 80.6067292616954, 9812.02: 72.38318528088872, 5.06: 108.87327766668194, 7.01: 107.43594849420701, 102.06: 0.8601721958702343, 703.01: 110.94894320185638, 611.01: 91.17686655858547, 203.04: 200.37153853150514, 408.01: 137.13296202238587, 612.02: 118.17963383270087, 606.02: 111.61384073542968, 303.01: 142.8336125547214, 6.04: 72.48362236009082, 5.05: 191.9054499992323, 606.01: 347.6667380401347, 6.03: 63.997612037102954, 203.05: 741.3151857653398, 3531.02: 11.184128733737152, 1401.02: 2.6751431692746204, 1402.01: 27.381273586148385, 9801.01: 78.83495090532337, 3521.01: 17.196596033560827, 4012.01: 6.426708463629465, 3501.06: 1.8027760421238377}

# %% [markdown]
# We now import the bike usage data of commuters in each census tract. The code here renames the columns to ones we can use, and prunes irrelevant data.

# %%
commute = pd.read_csv(data_path + 'Commute Data.csv')
commute = commute.iloc[[11]] # keeps only bike commute rate
commute = commute.iloc[:, 1::3] # keeps only total estimates, not male or female specific

new_column_names = []

for column_name in commute.columns:
    words = column_name.split()
    if len(words) >= 3:
        new_column_name = words[2]  # extract the census number from the original column name
    else:
        new_column_name = column_name  # edge case
    new_column_names.append(new_column_name[:-1])

commute.columns = new_column_names

commute.head()
# Out:
#     1.01  1.02  2.01  2.02  3.01  3.02  4.01  4.02  5.02  5.03  ... 9812.01  \
# 11  8.5%  2.1%  1.2%  0.6%  0.3%  0.3%  1.4%  0.5%  1.2%  0.6%  ...       -
#
#    9812.02  9813 9815.01 9815.02 9816 9817  9818 9819 9901.01
# 11    0.0%  0.0%       -       -    -    -  0.0%    -       -
#
# [1 rows x 235 columns]

# %% [markdown]
# We also import the population data of each census tract. This way we can observe trends in the data based on population density, which we feel would be an important metric to have.

# %%
census_pop = pd.read_csv(data_path + 'Census Population.csv')
census_pop = census_pop.iloc[[1]] # keeps only bike commute rate
census_pop = census_pop.iloc[:, 1::2] # keeps only total estimates, not male or female specific

new_column_names = []

for column_name in census_pop.columns:
    words = column_name.split()
    if len(words) >= 3:
        new_column_name = words[2]  # extract the census number from the original column name
    else:
        new_column_name = column_name  # edge case
    new_column_names.append(new_column_name[:-1])

census_pop.columns = new_column_names

census_pop.head()
# Out:
#     1.01   1.02   2.01   2.02   3.01   3.02   4.01   4.02   5.02   5.03  ...  \
# 1  1,734  3,979  4,375  3,892  2,719  3,231  4,898  3,795  5,382  2,099  ...
#
#   9812.01 9812.02 9813 9815.01 9815.02 9816 9817  9818 9819 9901.01
# 1       0     109   23       0       0    0    0  46.0    0       0
#
# [1 rows x 235 columns]

# %% [markdown]
# Now we can zip up the census tract bike usage with the bikelane frequency found earlier with the census tract as the key. This will allow us to find correlations between bike usage and frequency of bike lane in a given census tract. We also do this with bikelane connectivity, and in addition, zip up the popuation density of all tracts with each engineered feature so we can make a distinction in tract population density when we plot them.

# %%
frequency_trend = []

row = commute.iloc[0]

# for every census tract in the dataframe containing bike usage of every tract, add a three-tuple containing
# bike usage percentage, bikelane frequency, and population density to a list to plot later.
for col, val in row.items():
    if val == '-':
        continue
    cen = float(col)
    if cen in census_bikelane_freq:
        area = gdf.loc[gdf['NAME'] == str(cen)]['area_sq_m'].values[0]
        cPop = str(census_pop.loc[1, str(cen)])
        frequency_trend.append( (float(val.strip('%')), census_bikelane_freq[cen], float(cPop.replace(",", ""))/float(area)) )
    # print(f"Column name: {col}, Value: {val}")

# do the same for connectivity
connectivity_trend = []
for col, val in row.items():
    if val == '-':
        continue
    cen = float(col)
    if cen in census_bikelane_connectivity:
        area = gdf.loc[gdf['NAME'] == str(cen)]['area_sq_m'].values[0]
        cPop = str(census_pop.loc[1, str(cen)])
        connectivity_trend.append( (float(val.strip('%')), census_bikelane_connectivity[cen], float(cPop.replace(",", ""))/float(area)) )
    # print(f"Column name: {col}, Value: {val}")

# find mean population density so we can classify tracts in the scatter plot later
pop_density = []
for item in frequency_trend:
    pop_density.append(item[2])
pop_density = sorted(pop_density)
med_pop_density = (pop_density[(len(pop_density)-1) // 2] + pop_density[len(pop_density) // 2]) / 2
mean_pop_density = np.mean(pop_density)

print(frequency_trend)
print(connectivity_trend)
# print(commute.iloc[0]['8.06'])
# Out:
# [(8.5, 275.87397493226007, 0.0006446127399064049), (2.1, 213.59722297907504, 0.0003463310242171693), (1.2, 597.9947102971255, 0.0006783393702972485), (0.6, 557.6177128703736, 0.0006010322028196077), (0.3, 199.06489225068293, 0.00044208384535703303), (0.3, 254.19027622725005, 0.00047193853242356756), (1.4, 260.47266476671854, 0.0010557435841031687), (0.5, 196.4318392916069, 0.00043704141742321773), (1.2, 284.1440413940628, 0.00042296045897790023), (0.6, 277.6213827741046, 0.0013935098850547762), (4.5, 191.9054499992323, 0.001362240253060759), (2.7, 108.87327766668194, 0.0012359609618694469), (1.0, 362.8842624119073, 0.0007503773775449495), (0.0, 63.997612037102954, 0.0004905811595801934), (8.4, 72.48362236009082, 0.0007596136450986465), (5.5, 107.43594849420701, 0.00175345866945745), (4.6, 1252.1523708661136, 0.0008878680573407704), (5.9, 164.0195653781856, 0.0016243146898493577), (5.9, 740.872589338708, 0.000492990405035523), (5.7, 337.1443659207243, 0.0007774309765740026), (5.0, 240.72490800947557, 0.0001566862745558667), (0.0, 600.5349438360397, 0.001308684215957886), (0.5, 635.7210132283169, 0.0010954764743730673), (3.6, 787.8010367382534, 0.0015526138302252906), (3.9, 1570.76847123856, 0.0012267787888615145), (7.8, 264.4863184641426, 0.0020516207122940958), (0.0, 0.8601721958702343, 2.9409166246465337e-06), (4.8, 350.197845049256, 0.002796104810104972), (0.3, 252.18616261041865, 0.0031114684692924942), (2.9, 554.7272573476487, 0.001507605702757168), (0.1, 853.2271744159475, 0.0010642075370909396), (0.5, 638.8354779198783, 0.0006450309781911911), (3.4, 670.118670249156, 0.0019209840416726175), (4.1, 1067.2659424443673, 0.0019644736150313652), (2.8, 56.9213165177813, 0.001711433261143953), (0.7, 2457.5646993778755, 0.0008313006331776402), (0.7, 216.6980673430978, 0.0012474920621515305), (1.9, 200.37153853150514, 0.0007686169620020754), (0.9, 741.3151857653398, 0.0009925826990129494), (0.0, 142.8336125547214, 0.00034624685233509094), (0.6, 1400.2102294292374, 0.00046261544835087584), (1.6, 995.2163152254839, 0.000580158243767922), (2.3, 137.13296202238587, 0.00022490952790724927), (1.2, 389.3372305764069, 0.001017553884473969), (0.0, 108.27436418170896, 0.000519578733389215), (0.3, 80.6067292616954, 0.00035206748862681085), (1.6, 347.6667380401347, 0.001211583919651071), (7.5, 111.61384073542968, 8.944466146627327e-05), (0.0, 265.1065495399018, 0.0002895368736447424), (3.9, 351.2098063364071, 0.00024629271291192145), (0.7, 91.17686655858547, 0.0012901020963155766), (3.6, 186.2875572618486, 0.0002659936894884406), (1.0, 469.53367633293414, 0.0005864395012412178), (4.0, 532.1533012675208, 0.0001814498568120828), (0.0, 1546.5940864471668, 0.001819056964463719), (1.4, 800.7111212059617, 0.00028485440546612483), (0.3, 1586.5550052062183, 0.002091283161156449), (0.0, 1146.1944570405026, 0.002202714680852397), (2.2, 110.94894320185638, 0.0017235960141245802), (2.3, 337.0955715676647, 0.0008512003553021517), (3.0, 193.9833952620614, 0.0011294690858718011), (4.9, 681.9344034018761, 0.001495012000313441), (0.8, 562.3126380998299, 0.0020172977149946767), (0.0, 877.7801195158457, 0.001591616461074006), (2.7, 140.2123951619993, 0.0016486455791214062), (0.0, 1288.3103608569622, 0.0020565997261822056), (1.6, 396.4435395561209, 0.001742144200384304), (3.6, 576.1404681894506, 0.0010022489997035973), (4.2, 336.19565201571703, 0.0009573067838660631), (4.0, 505.684703443875, 0.0006129880439707233), (2.2, 655.8068666219688, 0.0005908753838289439), (0.0, 295.04449051489036, 0.0010523496875899205), (1.7, 218.98457808296405, 0.0007994417797841492), (0.0, 434.3050502973466, 0.0010854346464528818), (1.7, 179.72048651850122, 0.0006989133666264025), (8.0, 101.98419032822491, 0.0010621236073005843), (2.4, 647.3705412947198, 0.0006366840387379298), (0.4, 543.7789710778603, 0.00018836145108401666), (1.6, 81.64998242862187, 0.0001742378444600615), (1.5, 133.78782098294678, 0.0004376015925264037), (2.3, 86.04210922416371, 0.0010964172200444943), (1.9, 485.67 ...
# [(8.5, 8640.043441263477, 0.0006446127399064049), (2.1, 1083.1742799176207, 0.0003463310242171693), (1.2, 3557.457580532943, 0.0006783393702972485), (0.6, 3260.6213517879705, 0.0006010322028196077), (0.3, 1289.312724104007, 0.00044208384535703303), (0.3, 1263.5313565683912, 0.00047193853242356756), (1.4, 3156.1050950563067, 0.0010557435841031687), (0.5, 1054.077675076013, 0.00043704141742321773), (1.2, 853.078366916583, 0.00042296045897790023), (0.6, 14759.328076783806, 0.0013935098850547762), (4.5, 15508.072526772368, 0.001362240253060759), (2.7, 2258.158901461453, 0.0012359609618694469), (1.0, 4846.0611517368225, 0.0007503773775449495), (0.0, 1368.9435444843573, 0.0004905811595801934), (8.4, 6472.5436980903905, 0.0007596136450986465), (5.5, 7718.604543489547, 0.00175345866945745), (4.6, 42143.634876953474, 0.0008878680573407704), (5.9, 3844.812127836442, 0.0016243146898493577), (5.9, 3651.687417847147, 0.000492990405035523), (5.7, 5199.401396242352, 0.0007774309765740026), (5.0, 657.173674146557, 0.0001566862745558667), (0.0, 13148.359616933247, 0.001308684215957886), (0.5, 10746.963105884484, 0.0010954764743730673), (3.6, 11308.314961923146, 0.0015526138302252906), (3.9, 22269.441701802094, 0.0012267787888615145), (7.8, 20727.65896213665, 0.0020516207122940958), (0.0, 0.06436133938114076, 2.9409166246465337e-06), (4.8, 31025.92909564289, 0.002796104810104972), (0.3, 26276.16008894313, 0.0031114684692924942), (2.9, 8595.335207198521, 0.001507605702757168), (0.1, 21157.284638471392, 0.0010642075370909396), (0.5, 10643.690412004229, 0.0006450309781911911), (3.4, 37343.489941155494, 0.0019209840416726175), (4.1, 49043.52737531766, 0.0019644736150313652), (2.8, 7328.892989009503, 0.001711433261143953), (0.7, 19024.943061543432, 0.0008313006331776402), (0.7, 21258.916063327848, 0.0012474920621515305), (1.9, 10295.566855373518, 0.0007686169620020754), (0.9, 5483.780211856523, 0.0009925826990129494), (0.0, 1811.702376225066, 0.00034624685233509094), (0.6, 6330.702441373761, 0.00046261544835087584), (1.6, 3065.456182602864, 0.000580158243767922), (2.3, 162.9891842326898, 0.00022490952790724927), (1.2, 2197.6623144224122, 0.001017553884473969), (0.0, 329.3613003490028, 0.000519578733389215), (0.3, 137.87457122000438, 0.00035206748862681085), (1.6, 19076.783164752112, 0.001211583919651071), (7.5, 637.030670314065, 8.944466146627327e-05), (0.0, 5885.131944769883, 0.0002895368736447424), (3.9, 747.2350729819951, 0.00024629271291192145), (0.7, 1711.3579235094903, 0.0012901020963155766), (3.6, 2031.2573339180622, 0.0002659936894884406), (1.0, 6198.537218009263, 0.0005864395012412178), (4.0, 4445.688013929719, 0.0001814498568120828), (0.0, 50046.805079256505, 0.001819056964463719), (1.4, 2531.7205000171216, 0.00028485440546612483), (0.3, 58955.96559443525, 0.002091283161156449), (0.0, 27415.003919581493, 0.002202714680852397), (2.2, 7471.246378134995, 0.0017235960141245802), (2.3, 13439.786043905011, 0.0008512003553021517), (3.0, 3796.6458547759316, 0.0011294690858718011), (4.9, 43789.099603113245, 0.001495012000313441), (0.8, 9622.55781817495, 0.0020172977149946767), (0.0, 105139.21262613904, 0.001591616461074006), (2.7, 18497.718703137572, 0.0016486455791214062), (0.0, 197513.12539659944, 0.0020565997261822056), (1.6, 28372.657394427424, 0.001742144200384304), (3.6, 6689.508048847525, 0.0010022489997035973), (4.2, 4440.94423913287, 0.0009573067838660631), (4.0, 4047.8710612769337, 0.0006129880439707233), (2.2, 3839.4911769401806, 0.0005908753838289439), (0.0, 3006.474719687914, 0.0010523496875899205), (1.7, 1982.175049853638, 0.0007994417797841492), (0.0, 29061.724570743525, 0.0010854346464528818), (1.7, 1347.0826881063049, 0.0006989133666264025), (8.0, 1978.2151131488217, 0.0010621236073005843), (2.4, 6620.63363894401, 0.0006366840387379298), (0.4, 583.2494004895009, 0.00018836145108401666), (1.6, 308.3133620205759, 0.0001742378444600615), (1.5, 476.5721789236023, 0.0004376015925264037), (2.3, 1037.3275457622462, 0.0010964172200444943), ...

# %% [markdown]
# ### Graphing Data + Trend Analysis

# %% [markdown]
# Now we can graph this list of tuples to see if there exists a trend! First, we will graph the raw data. Blue points represent the census tracts that with a greater than average population density (compared to all census tracts), and red points represent those with less than average. Keep in mind that the values on the Y axis aren't represented by any unit, and for the purposes of this study only used to compare one tract to another.

# %%
import matplotlib.pyplot as plt

bike_usage = [item[0] for item in frequency_trend]  # percentage of bike commuters
lane_freq = [item[1] for item in frequency_trend]  # freq of bike lanes
pop_density = [item[2] for item in frequency_trend] # population density
colors = ['blue' if i > mean_pop_density else 'red' for i in pop_density]
print(len(bike_usage))

plt.figure(figsize=(8, 6))
plt.scatter(bike_usage, lane_freq, c=colors, marker='o')
# plt.ylim(0, 1750)
plt.xlabel('Percentage of Bike Commuters')
plt.ylabel('Frequency of Bike Lanes')
plt.title('Bike Commuters vs Frequency of Bike Lanes')
plt.grid(True)
plt.show()
# Out:
# 108

# %% [markdown]
# The graph above shows a very scattered graph without much correlation at all. What we do see, though, is an abundance of census tracts with abolutely no bike usage -- this could be the effect of many outside causes. Maybe those tracts have few people/are not in residential areas, or the area is too far from metro areas to warant cycling, etc. As such, we can try to manually remove the 0 bike usage tracts (and hand remove one outlier) by only considering points with at least 0.3% cycling. This percentage was used after some trial and error in seeing which threshold would be reasonable to hit while finding the most observable trend. We can also fit lines of best fit determined by linear regression to these data points -- one for each level of population density.

# %%
from sklearn.linear_model import LinearRegression

frequency_trend = [item for item in frequency_trend if item[0] > 0.3 and item[1] < 2300] # filter out outliers
bike_usage = [item[0] for item in frequency_trend]  # percentage of bike commuters
lane_freq = [item[1] for item in frequency_trend]  # freq of bike lanes
pop_density = [item[2] for item in frequency_trend]
colors = ['blue' if i > mean_pop_density else 'red' for i in pop_density]

red_bike_usage = [bike_usage[i] for i in range(len(bike_usage)) if colors[i] == 'red']
red_lane_freq = [lane_freq[i] for i in range(len(lane_freq)) if colors[i] == 'red']
blue_bike_usage = [bike_usage[i] for i in range(len(bike_usage)) if colors[i] == 'blue']
blue_lane_freq = [lane_freq[i] for i in range(len(lane_freq)) if colors[i] == 'blue']

# linear regression
red_model = LinearRegression()
red_bike_usage = np.array(red_bike_usage).reshape(-1, 1)
red_model.fit(red_bike_usage, red_lane_freq)
blue_model = LinearRegression()
blue_bike_usage = np.array(blue_bike_usage).reshape(-1, 1)
blue_model.fit(blue_bike_usage, blue_lane_freq)

plt.figure(figsize=(8, 6))
plt.scatter(bike_usage, lane_freq, c=colors, marker='o')
plt.plot(red_bike_usage, red_model.predict(red_bike_usage), color='red', linewidth=2)
plt.plot(blue_bike_usage, blue_model.predict(blue_bike_usage), color='blue', linewidth=2)

# plt.ylim(0, 1750)
plt.xlabel('Percentage of Bike Commuters')
plt.ylabel('Frequency of Bike Lanes')
plt.title('Bike Commuters vs Frequency of Bike Lanes')
plt.grid(True)
plt.show()

# %% [markdown]
# However, even after pruning the tracts with very little to no bike usage, we are left with no trend. You could argue that the best fit lines could represent something, but even then anything they represent would be weak as the deviation of the points is far too high. As such, we have shown that **the percentage of bike commuters is not significantly affected by our metric of frequency** -- we suspect that other factors matter more than just pure frequency, such as proximity to metro areas, greenways, transit, or income level of the tract.

# %% [markdown]
# Now, we will also plot the data for bikelane connectivity, first starting with no filtering.

# %%
bike_usage = [item[0] for item in connectivity_trend]  # percentage of bike commuters
lane_connectivity = [item[1] for item in connectivity_trend]  # freq of bike lanes
pop_density = [item[2] for item in connectivity_trend]
colors = ['blue' if i > mean_pop_density else 'red' for i in pop_density]

plt.figure(figsize=(8, 6))
plt.scatter(bike_usage, lane_connectivity, marker='o', c=colors)
# plt.ylim(0, 50000)
plt.xlabel('Percentage of Bike Commuters')
plt.ylabel('Connectivity of Bike Lanes')
plt.title('Bike Commuters vs Connectivity of Bike Lanes')
plt.grid(True)
plt.show()

# %% [markdown]
# As we can see above, there are a few statistical outliers that significantly impact our observation of the data. Let's process this data by getting rid of the 0 bike usage tracts due to the reasons we said earlier.

# %%
connectivity_trend = [item for item in connectivity_trend if item[0] > 0.3] # filter out outliers
bike_usage = [item[0] for item in connectivity_trend]  # percentage of bike commuters
lane_connectivity = [item[1] for item in connectivity_trend]  # freq of bike lanes
pop_density = [item[2] for item in connectivity_trend]
colors = ['blue' if i > mean_pop_density else 'red' for i in pop_density]

red_bike_usage = [bike_usage[i] for i in range(len(bike_usage)) if colors[i] == 'red']
red_lane_freq = [lane_connectivity[i] for i in range(len(lane_connectivity)) if colors[i] == 'red']
blue_bike_usage = [bike_usage[i] for i in range(len(bike_usage)) if colors[i] == 'blue']
blue_lane_freq = [lane_connectivity[i] for i in range(len(lane_connectivity)) if colors[i] == 'blue']

# linear regression
red_model = LinearRegression()
red_bike_usage = np.array(red_bike_usage).reshape(-1, 1)
red_model.fit(red_bike_usage, red_lane_freq)
blue_model = LinearRegression()
blue_bike_usage = np.array(blue_bike_usage).reshape(-1, 1)
blue_model.fit(blue_bike_usage, blue_lane_freq)

plt.figure(figsize=(8, 6))
plt.scatter(bike_usage, lane_connectivity, c=colors, marker='o')
plt.plot(red_bike_usage, red_model.predict(red_bike_usage), color='red', linewidth=2)
plt.plot(blue_bike_usage, blue_model.predict(blue_bike_usage), color='blue', linewidth=2)

# plt.ylim(0, 50000)
plt.xlabel('Percentage of Bike Commuters')
plt.ylabel('Connectivity of Bike Lanes')
plt.title('Bike Commuters vs Connectivity of Bike Lanes')
plt.grid(True)
plt.show()

# %% [markdown]
# Now this is a more interesting graph. We can see a clear positive trend in highly dense census tracts, suggesting that **the connectivity of bike lanes to other bike lanes (and in general other areas) have a larger impact than frequency does in tracts of dense population.** This trend appears despite a number of outliers for high-density populations that show high cycling percentages despite low connectivity (which could maybe be the result of dense places having shorter cycling distances), and supports the notion that we should be implementing more *connective* bike lanes and being more mindful of their placement than simply implenting *more* of them.
#
# Another interesting trend that comes up is how little connectivity impacts the low-density tracts. We suspect that this could be caused because of the following factors:
# - Less dense tracts implies that they are more residential in nature / further from metro areas, and thus connectivity would not matter if the distance is too far for cycling
# - Less dense tracts' cycling commuters would cycle regardless of connectivity of bike lanes (they are used to the more car-centric nature of these tracts)\
#
# But we cannot overlook the majority of low-density tracts having low connectivity AND usage, which tracks with our preconceptions of less-dense areas. As these low-usage low-density tracts heavily outnumber the low-density tracts with high usage, there must be another factor barring the people from these tracts from biking -- after all, the frequency scatterplot shows that the tracts are not lacking in bikelane frequency. This could be something to look into for our extension project.

# %% [markdown]
# This marks the end of this particular branch of insight for Livable Streets Team C. Hopefully these observations are useful in deciding what to do next regarding bike lanes in Boston!

# %% [markdown]
# ### Data Sources
# - Existing Bike Network GeoJSON: https://data.boston.gov/dataset/existing-bike-network-2023
# - Tract Areas (Landmass) Shapefiles: https://www.census.gov/cgi-bin/geo/shapefiles/index.php?year=2023&layergroup=Census+Tracts
# - Census Tract Commute Data: https://data.census.gov/table/ACSST5Y2022.S0801?g=050XX00US25025$1400000
# - Census Tract Population Data: https://data.census.gov/table/ACSDP5Y2022.DP05?g=050XX00US25025$1400000
